# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')
import scipy as sp
from scipy import interpolate
from scipy import integrate

# %%
#!pwd

# %%
dataFl=pd.read_table('/data/wjuan/local_lab_computer/fep_yoda_dooku_script/yoda-open305/dA_rep1.txt',
                     header=None,delim_whitespace=True)
dataFl.columns=['La','dA']

#dataF1=datFl.iloc[::-1]
#print datFl.iloc[::-1]
#print dataFl

plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')
plt.figure(figsize=(18,4))
#plt.xlim(0,100)
#plt.plot(dataL.La[0:12],dataL.dA[0:12],'g',label='rmsd-0.28ns') 
#plt.plot(dataWW.La[0:12],dataWW.dA[0:12],'b',label='rmsd-2.8ns') 
#plt.plot(dataF.La[0:16],dataF.dA[0:16],'r',label='rmsd-3.4ns') 
#plt.plot(dataM.La[0:16],dataM.dA[0:16],'k',label='rmsd-6.8ns')
plt.plot(dataFl.La[0:20],dataFl.dA[0:20],'y',label='rmsd-4ns')
plt.xlabel(r"Lambda",color="black",fontsize=36)
plt.ylabel(r"dA/dLamda",color="black",fontsize=36)
plt.tick_params(axis='x', colors='black')
plt.tick_params(axis='y', colors='black')
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend()
plt.legend(fontsize=20)
plt.show()

#data_int=integrate.cumtrapz(dataWW.dA[0:12],dataWW['La'][0:12],initial=0)
#data_intL=integrate.cumtrapz(dataL.dA[0:12],dataL['La'][0:12],initial=0)
#data_intF=integrate.cumtrapz(dataF.dA[0:16],dataF['La'][0:16],initial=0)
#data_intM=integrate.cumtrapz(dataM.dA[0:16],dataM['La'][0:16],initial=0)
data_intFl=integrate.cumtrapz(dataFl.dA[0:20],dataFl['La'][0:20],initial=0)

plt.figure(figsize=(18,4))
#plt.plot(dataL['La'][0:12],data_intL,'g-',label='rmsd integral-0.28ns')
#plt.plot(dataWW['La'][0:12],data_int,'b-',label='rmsd integral-2.8ns')
#plt.plot(dataF['La'][0:16],data_intF,'r-',label='rmsd integral-3.4ns')
#plt.plot(dataM['La'][0:16],data_intM,'k-',label='rmsd integral-6.8ns')
plt.plot(dataFl['La'][0:20],data_intFl,'y-',label='rmsd integral-4ns')
plt.legend()
plt.legend(fontsize=15)
plt.xlabel(r"Lambda",color="black",fontsize=36)
plt.ylabel(r"dA",color="black",fontsize=36)
plt.tick_params(axis='x', colors='black')
plt.tick_params(axis='y', colors='black')
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)

print ("8ns, final FEP= %s" %data_intFl[19])
print  (data_intFl)
# Out:
# 8ns, final FEP= 5.151029918850001
# [0.         0.593275   0.91909125 1.3408675  1.77545375 2.2096475
#  2.61218375 2.94332375 3.4932845  3.70682188 3.90120425 4.2002655
#  4.592435   4.81614    4.96861    5.05686235 5.11114905 5.14743647
#  5.15070448 5.15102992]

# %%
dataFl=pd.read_table('/data/wjuan/local_lab_computer/fep_yoda_dooku_script/yoda-open293/dA_rep1.txt',
                     header=None,delim_whitespace=True)
dataFl.columns=['La','dA']

#dataF1=datFl.iloc[::-1]
#print datFl.iloc[::-1]
#print dataFl

plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')
plt.figure(figsize=(18,4))
#plt.xlim(0,100)
#plt.plot(dataL.La[0:12],dataL.dA[0:12],'g',label='rmsd-0.28ns') 
#plt.plot(dataWW.La[0:12],dataWW.dA[0:12],'b',label='rmsd-2.8ns') 
#plt.plot(dataF.La[0:16],dataF.dA[0:16],'r',label='rmsd-3.4ns') 
#plt.plot(dataM.La[0:16],dataM.dA[0:16],'k',label='rmsd-6.8ns')
plt.plot(dataFl.La[0:20],dataFl.dA[0:20],'y',label='rmsd-4ns')
plt.xlabel(r"Lambda",color="black",fontsize=36)
plt.ylabel(r"dA/dLamda",color="black",fontsize=36)
plt.tick_params(axis='x', colors='black')
plt.tick_params(axis='y', colors='black')
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend()
plt.legend(fontsize=20)
plt.show()

#data_int=integrate.cumtrapz(dataWW.dA[0:12],dataWW['La'][0:12],initial=0)
#data_intL=integrate.cumtrapz(dataL.dA[0:12],dataL['La'][0:12],initial=0)
#data_intF=integrate.cumtrapz(dataF.dA[0:16],dataF['La'][0:16],initial=0)
#data_intM=integrate.cumtrapz(dataM.dA[0:16],dataM['La'][0:16],initial=0)
data_intFl=integrate.cumtrapz(dataFl.dA[0:20],dataFl['La'][0:20],initial=0)

plt.figure(figsize=(18,4))
#plt.plot(dataL['La'][0:12],data_intL,'g-',label='rmsd integral-0.28ns')
#plt.plot(dataWW['La'][0:12],data_int,'b-',label='rmsd integral-2.8ns')
#plt.plot(dataF['La'][0:16],data_intF,'r-',label='rmsd integral-3.4ns')
#plt.plot(dataM['La'][0:16],data_intM,'k-',label='rmsd integral-6.8ns')
plt.plot(dataFl['La'][0:20],data_intFl,'y-',label='rmsd integral-4ns')
plt.legend()
plt.legend(fontsize=15)
plt.xlabel(r"Lambda",color="black",fontsize=36)
plt.ylabel(r"dA",color="black",fontsize=36)
plt.tick_params(axis='x', colors='black')
plt.tick_params(axis='y', colors='black')
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)

print ("8ns, final FEP= %s" %data_intFl[19])
print  (data_intFl)
# Out:
# 8ns, final FEP= 5.7475491577
# [0.         0.828025   1.24510375 1.712865   2.2504075  2.76019875
#  3.1844975  3.550545   4.13121075 4.35600413 4.53992837 4.82791488
#  5.23096587 5.44544088 5.57276188 5.65417572 5.70752282 5.74425236
#  5.74726923 5.74754916]
