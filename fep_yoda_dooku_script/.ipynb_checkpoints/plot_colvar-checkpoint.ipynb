# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')
import scipy.stats
import matplotlib
from matplotlib import pyplot as plt
import gc
#import mdtraj as md
#import pytraj as pt
import numpy as np
import scipy as sp
from scipy.interpolate import CubicSpline
import pandas as pd
import collections
from ipywidgets import FloatProgress
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.font_manager import FontProperties
from scipy.spatial import Delaunay
import mpl_toolkits
import mpl_toolkits.axes_grid1
from mpl_toolkits.mplot3d import Axes3D
import copy
import sys
import json
import gc
import os.path
import matplotlib
#import f90nml

# %%
#!pwd
def runningMeanFast(x, N):
    return np.convolve(x, np.ones((N,))/N)[(N-1):]

# %%
#!python -m pip install --upgrade pip

# %%
#!pip install mdtraj

# %%
dataDir='./' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job4.127.sort' in datFile]
txtFiles=[datFile for datFile in datFiles if 'sort' in datFile]
print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
for restFile in parmData:
    figure(num=None, figsize=(28, 6), dpi=80, facecolor='w', edgecolor='k')
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    #delta=(d-1)*1
    delta=0
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','dist','r1','r2','r3','r4','r5','r6','r7','r8','r9','r10','r11',
                     'r12','r13','r14','r15','r16','r17','r18','r19']
    #plt.title("dooku-close job0 state",fontsize=30)
    #plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.plot(delta+negData['Frame']*0.000001,negData['dist'],color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"RMSD ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    #plt.axhline(y=3.9,color='b',linestyle='-')
    #plt.axhline(y=9.9,color='r',linestyle='-')
    #plt.axhline(y=0,color='b',linestyle='-')
    #plt.axhline(y=2.4,color='r',linestyle='-')
    #plt.legend(fontsize=20)
    #d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
    plt.show()
#plt.title('yoda-open colvar output',fontsize=30)
#plt.show()
# Out:
# ['fep.job4.127.sort.colvars.traj.txt']
# Replica colvars over trajectories
# loading fluctuation data from ./fep.job4.127.sort.colvars.traj.txt

# %%
dataDir='./' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job4.0.sort' in datFile]
txtFiles=[datFile for datFile in datFiles if 'sort' in datFile]
print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
for restFile in parmData:
    figure(num=None, figsize=(28, 6), dpi=80, facecolor='w', edgecolor='k')
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    #delta=(d-1)*1
    delta=0
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','dist','r1','r2','r3','r4','r5','r6','r7','r8','r9','r10','r11',
                     'r12','r13','r14','r15','r16','r17','r18','r19']
    #plt.title("dooku-close job0 state",fontsize=30)
    #plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.plot(delta+negData['Frame']*0.000001,negData['dist'],color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"Distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    #plt.axhline(y=3.9,color='b',linestyle='-')
    #plt.axhline(y=9.9,color='r',linestyle='-')
    #plt.axhline(y=0,color='b',linestyle='-')
    #plt.axhline(y=2.4,color='r',linestyle='-')
    #plt.legend(fontsize=20)
    #d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
    plt.show()
#plt.title('yoda-open colvar output',fontsize=30)
#plt.show()
# Out:
# ['fep.job4.0.sort.colvars.traj.txt']
# Replica colvars over trajectories
# loading fluctuation data from ./fep.job4.0.sort.colvars.traj.txt

# %%
dataDir='./fep_yoda_close/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*1
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=9.9,color='r',linestyle='-')
    plt.axhline(y=3.7,color='b',linestyle='-')
    plt.axhline(y=7.3,color='r',linestyle='-')
    plt.axhline(y=1.9,color='r',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('yoda-close colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.0.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.1.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.10.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.100.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.101.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.102.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.103.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.104.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.105.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.106.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.107.colvars.traj
# ...

# %%
dataDir='./fep_dooku_open/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*1
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=7.3,color='b',linestyle='-')
    plt.axhline(y=11.9,color='r',linestyle='-')
    plt.axhline(y=2.4,color='r',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('dooku-open colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.0.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.1.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.10.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.100.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.101.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.102.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.103.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.104.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.105.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.106.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job0.107.colvars.traj
# ...

# %%
dataDir='./fep_dooku_close/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job2' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*1
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=4,color='b',linestyle='-')
    plt.axhline(y=16,color='r',linestyle='-')
    plt.axhline(y=3,color='r',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('dooku-close colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.0.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.1.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.10.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.100.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.101.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.102.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.103.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.104.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.105.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.106.colvars.traj
# loading fluctuation data from ./fep_dooku_close/test_traj/fep.job2.107.colvars.traj
# ...

# %%
dataDir='./fep_dooku_open/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job3' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*0.4
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=7.3,color='b',linestyle='-')
    plt.axhline(y=13,color='r',linestyle='-')
    plt.axhline(y=2.4,color='r',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('dooku-open colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.0.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.1.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.10.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.100.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.101.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.102.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.103.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.104.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.105.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.106.colvars.traj
# loading fluctuation data from ./fep_dooku_open/test_traj/fep.job3.107.colvars.traj
# ...

# %%
dataDir='./fep_yoda_close/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*0.5
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.001*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.001*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=3.7,color='b',linestyle='-')
    plt.axhline(y=16,color='r',linestyle='-')
    plt.axhline(y=3,color='r',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('yoda-close colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.0.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.1.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.10.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.100.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.101.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.102.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.103.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.104.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.105.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.106.colvars.traj
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0.107.colvars.traj
# ...

# %%
dataDir='./check_folder/3lipids/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job3' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]

#int txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "
d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*0.4
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist','l299','d299','l310','d310',
                     'l191','d191','l123','d123','l64','d64','l61','d61',
                    'l81','d81','l53','d53','l137','d137']
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['rmsd'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    plt.axhline(y=0,color='b',linestyle='-')
    plt.axhline(y=6.169,color='g',linestyle='-')
    plt.axhline(y=7.745,color='k',linestyle='-')
    plt.axhline(y=0,color='b',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./check_folder/3lipids/fep.job3.0.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.1.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.10.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.100.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.101.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.102.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.103.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.104.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.105.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.106.colvars.traj
# loading fluctuation data from ./check_folder/3lipids/fep.job3.107.colvars.traj
# ...

# %%
dataDir='.' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0' in datFile]
txtFiles=[datFile for datFile in datFiles if 'traj' in datFile]
print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "
d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    print ('loading fluctuation data from %s'%restFile)
    delta=(d-1)*1
    negData=pd.read_table(restFile,header=None,delim_whitespace=True)
    negData.columns=['Frame','rmsd','dist','l299','d299','l310','d310',
                     'l191','d191','l123','d123','l64','d64','l61','d61',
                    'l81','d81','l53','d53','l137','d137']
    plt.scatter(delta+negData['Frame']*0.001*0.001,negData['l310'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    plt.scatter(delta+negData['Frame']*0.001*0.001,negData['d310'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"distance ($\AA$)",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.show()
# Out:
# ['fep.job0.0.colvars.traj', 'fep.job0.1.colvars.traj', 'fep.job0.10.colvars.traj', 'fep.job0.100.colvars.traj', 'fep.job0.101.colvars.traj', 'fep.job0.102.colvars.traj', 'fep.job0.103.colvars.traj', 'fep.job0.104.colvars.traj', 'fep.job0.105.colvars.traj', 'fep.job0.106.colvars.traj', 'fep.job0.107.colvars.traj', 'fep.job0.108.colvars.traj', 'fep.job0.109.colvars.traj', 'fep.job0.11.colvars.traj', 'fep.job0.110.colvars.traj', 'fep.job0.111.colvars.traj', 'fep.job0.112.colvars.traj', 'fep.job0.113.colvars.traj', 'fep.job0.114.colvars.traj', 'fep.job0.115.colvars.traj', 'fep.job0.116.colvars.traj', 'fep.job0.117.colvars.traj', 'fep.job0.118.colvars.traj', 'fep.job0.119.colvars.traj', 'fep.job0.12.colvars.traj', 'fep.job0.120.colvars.traj', 'fep.job0.121.colvars.traj', 'fep.job0.122.colvars.traj', 'fep.job0.123.colvars.traj', 'fep.job0.124.colvars.traj', 'fep.job0.125.colvars.traj', 'fep.job0.126.colvars.traj', 'fep.job0.127.colvars.traj', 'fep.job0.13.colvars.traj', 'fep.job0.14.colvar
# ...

# %%
dataDir='/home/wenjuan/work/protein/Piezo/porehelix_cg_aa/revesedMap/namd/bulk-popc'
filepath='/'.join([dataDir,'resid38_P.xvg'])
dataLig=pd.read_table(filepath,header=None,delim_whitespace=True)
dataLig.columns=['Frame','X','Y','Z','x0','y0','z0']

filepath='/'.join([dataDir,'otherP.midplane.xvg'])
dataLig2=pd.read_table(filepath,header=None,delim_whitespace=True)
dataLig2.columns=['Frame','X','Y','Z','x0','y0','z0']

dataLig['dz']=dataLig['Z']-dataLig2['Z']

plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')

fig,ax1 = plt.subplots(figsize=(18,12))

ax1.plot(dataLig['Frame']*0.010,dataLig['dz'],'b',label='diffZ')
#ax1.plot(dataProt['Frame']*0.001*0.001,dataLig['Z'],'r',label='prot z-cor')
#ax1.plot(dataProt['Frame']*0.001*0.001,dataLig['Z'],'g',label='lig z-cor')

#ax1.plot(dataK['Time']*0.001,dataK['Pxy'],'r',label='orginal',alpha=0.2)
#ax1.set_xlim(0,480)
ax1.set_ylabel('distance ($\AA$)',color="black",fontsize=36)
#ax1.legend(loc='lower right')
#ax1.set_title('xy plane ETDM and cx26 COM distance',fontsize=36)
ax1.tick_params(axis='x', colors='black')
ax1.tick_params(axis='y', colors='black')
ax1.set_xlabel(r"Time ns",color="black",fontsize=30)
ax1.tick_params(axis='y', which='major', labelsize=30)
ax1.tick_params(axis='x', which='major', labelsize=30)
ax1.legend(fontsize=25)

print "mean last 5ns:"
print np.mean(np.absolute(dataLig['dz'][501:1000]))
print "maximum last 5ns:"
print np.max(np.absolute(dataLig['dz'][501:1000]))
print dataLig['dz'][0:3]
# Out:
# mean last 5ns:
# 1.4786462925851702
# maximum last 5ns:
# 5.1267
# 0   -4.0407
# 1   -4.4487
# 2   -4.5064
# Name: dz, dtype: float64

# %%
dataDir='./fep_yoda_open/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0_3' in datFile]
txtFiles=[datFile for datFile in datFiles if 'history' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*3.16
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','repID']
    plt.title("yoda-open job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['repID'],s=2,color='black')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    #plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"Replica ID",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    #plt.axhline(y=3.9,color='b',linestyle='-')
    plt.axhline(y=128,color='r',linestyle='-')
    #plt.axhline(y=0,color='b',linestyle='-')
    #plt.axhline(y=2.4,color='r',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('yoda-open colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.0.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.1.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.10.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.100.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.101.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.102.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.103.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.104.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.105.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.106.history
# loading fluctuation data from ./fep_yoda_open/test_traj/fep.job0_3.107.history
# ...

# %%
dataDir='./fep_yoda_close/test_traj/' #set this to the appropriate directory name
dataFiles=np.sort(os.listdir(dataDir))

datFiles=[datFile for datFile in dataFiles if 'fep.job0_3' in datFile]
txtFiles=[datFile for datFile in datFiles if 'history' in datFile]
#print txtFiles
parmData=['%s'%restFile for restFile in txtFiles ]

import matplotlib
matplotlib.rc('axes',edgecolor='k')
from matplotlib.pyplot import figure
print "Replica colvars over trajectories "

d=1
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
for restFile in parmData:
    filepath=''.join([dataDir,'%s'%restFile])
    print ('loading fluctuation data from %s'%filepath)
    delta=(d-1)*4.8
    negData=pd.read_table(filepath,header=None,delim_whitespace=True)
    negData.columns=['Frame','repID']
    plt.title("dooku-close job0 state",fontsize=30)
    plt.scatter(delta+negData['Frame']*0.002*0.001,negData['repID'],s=2,color='k')
    #plt.scatter(delta+negData['Frame']*0.001*0.001,negData['lipZ'],s=2,color='red')
    #plt.scatter(delta+negData['Frame']*0.002*0.001,negData['dist'],s=2,color='green')
    plt.xlabel(r"Time (ns)",fontsize=22)
    plt.ylabel(r"Replica ID",fontsize=22)
    plt.tick_params(axis='x', which='major', labelsize=28)
    plt.tick_params(axis='y', which='major', labelsize=28)
    #plt.axhline(y=3.9,color='b',linestyle='-')
    plt.axhline(y=128,color='r',linestyle='-')
    #plt.axhline(y=0,color='b',linestyle='-')
    #plt.axhline(y=2.4,color='r',linestyle='-')
    #plt.legend(fontsize=20)
    d=d+1
    #plt.yticks(np.arange(0,200,45))
    #plt.ylim(-5.5,1.5)
    #plt.xlim(0,2)
plt.title('yoda-close colvar output',fontsize=30)
plt.show()
# Out:
# Replica colvars over trajectories
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.0.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.1.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.10.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.100.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.101.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.102.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.103.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.104.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.105.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.106.history
# loading fluctuation data from ./fep_yoda_close/test_traj/fep.job0_3.107.history
# ...

# %%
dataDir='/home/wenjuan/work/protein/cx26_ethidium/wt_cx26/frmAnton/100ns_n200mv'
filepath='/'.join([dataDir,'box2.txt'])
dataLig=pd.read_table(filepath,header=None,delim_whitespace=True)
dataLig.columns=['Frame','X','Y','Z']

plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')

fig,ax1 = plt.subplots(figsize=(12,8))

print np.average(dataLig['Z'])

ax1.plot(dataLig['Frame']*0.2,dataLig['Z'],'b',label='box Z')
ax1.plot(dataLig['Frame']*0.2,dataLig['X'],'r',label='box X',alpha=0.9)
#ax1.set_xlim(0,480)
ax1.set_ylabel('Distance',color="black",fontsize=36)
#ax1.legend(loc='lower right')
ax1.tick_params(axis='x', colors='black')
ax1.tick_params(axis='y', colors='black')
ax1.set_xlabel(r"Time ns",color="black",fontsize=20)
ax1.tick_params(axis='y', which='major', labelsize=20)
ax1.tick_params(axis='x', which='major', labelsize=20)
ax1.legend(fontsize=25)
# Out:
# 142.680895

# %%
dataDir='/home/wenjuan/work/protein/cx26_ethidium/wt_cx26/frmAnton/'
filepath='/'.join([dataDir,'rmsd_noloop_p400mv.xvg'])
dataLig1=pd.read_table(filepath,header=None,delim_whitespace=True)
dataLig1.columns=['Frame','rmsd']

filepath='/'.join([dataDir,'rmsd_noloop_n400mv.xvg'])
dataProt1=pd.read_table(filepath,header=None,delim_whitespace=True)
dataProt1.columns=['Frame','rmsd']
#dataProt1['R']=np.sqrt((dataLig1.X-dataProt1.X)*(dataLig1.X-dataProt1.X)+(dataLig1.Y-dataProt1.Y)*(dataLig1.Y-dataProt1.Y))




plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')

fig,ax1 = plt.subplots(figsize=(28,12))

#ax1.scatter(dataProt1['Frame']*0.2,dataProt1['R'],color='cyan',label='xy Radius')
ax1.scatter(dataLig1['Frame']*0.4,dataLig1['rmsd'],color='black',label='rmsd wt26 +400mv')
ax1.scatter(dataProt1['Frame'][1:498]*0.2,dataProt1['rmsd'][1:498],color='cyan',label='rmsd wt26 -400mv')
ax1.scatter(dataProt1['Frame'][499:5460]*0.2,dataProt1['rmsd'][499:5460],color='cyan',label='rmsd wt26 -400mv')
ax1.scatter(dataProt1['Frame'][5461:10452]*0.2,dataProt1['rmsd'][5461:10452],color='cyan',label='rmsd wt26 -400mv')
ax1.scatter(dataProt1['Frame'][10453:15444]*0.4-3100,dataProt1['rmsd'][10453:15444],color='cyan',label='rmsd wt26 -400mv')
#ax1.scatter(1100+dataProt['Frame']*0.4,dataProt['R'],color='b',label='xy Radius')
#ax1.scatter(1100+dataProt['Frame']*0.4,dataProt['Z'],color='r',label='prot z-cor')
#ax1.scatter(1100+dataProt['Frame']*0.4,dataLig['Z'],color='g',label='lig z-cor')
#ax1.scatter(3100+dataProt2['Frame']*0.4,dataProt2['R'],color='b')
#ax1.scatter(3100+dataProt2['Frame']*0.4,dataProt2['Z'],color='r')
#ax1.scatter(3100+dataProt2['Frame']*0.4,dataLig2['Z'],color='g')
#ax1.plot(dataK['Time']*0.001,dataK['Pxy'],'r',label='orginal',alpha=0.2)
#ax1.set_xlim(0,480)
ax1.set_ylabel('xy-plane distance',color="black",fontsize=36)
#ax1.legend(loc='lower right')
ax1.set_title('xy plane ETDM and cx26 COM distance +400mV',fontsize=36)
ax1.tick_params(axis='x', colors='black')
ax1.tick_params(axis='y', colors='black')
ax1.set_xlabel(r"Time ns",color="black",fontsize=30)
ax1.tick_params(axis='y', which='major', labelsize=30)
ax1.tick_params(axis='x', which='major', labelsize=30)
ax1.legend(fontsize=25)

# %%
plt.rcParams['axes.facecolor']='white'
import matplotlib
matplotlib.rc('axes',edgecolor='k')

fig,ax1 = plt.subplots(figsize=(18,12))

ax1.plot(z_len,dataK['epsilonK'],'b',label='16nm-K')
ax1.plot(z_len,dataNa['epsilonNa'],'r',label='16nm-Na')
ax1.set_xlabel('Z-axis in Angstrom')
ax1.set_xlim(0,480)
ax1.set_ylabel('Epsilon',color="black",fontsize=16)
ax1.legend(loc='best')
ax1.legend(loc='lower right')
ax1.set_title('Epsilon changes over Z-axis for K/Na ion, slab=5A',fontsize=16)
ax1.tick_params(axis='x', colors='black')
ax1.tick_params(axis='y', colors='black')
ax1.set_xlabel(r"Z-position ($\AA$)",color="black",fontsize=16)
ax1.tick_params(axis='y', which='major', labelsize=13)

ax2 =ax1.twinx()
ax2.plot(groupedK.mean()*unit,linestyle='-.',color='blue',label='16nm-K-PME')
ax2.plot(groupedNa.mean()*unit+groupN.mean()*unit,linestyle=':',color='red',label='16nm-Na-PME')
ax2.legend(loc='best')
ax2.legend(loc='upper right')
#ax3.set_ylim(-80,150)
ax2.set_ylabel('Potential (mV)',color="black",fontsize=16)
ax2.tick_params(axis='x', colors='black')
ax2.tick_params(axis='y', colors='black')
ax2.tick_params(axis='y', which='major', labelsize=13)
#ax4 =ax1.twinx()


plt.show()

# %%
data=pd.read_table('6nm/Na_200mM/volmap_HS.txt',header=None,delim_whitespace=True)
#data=pd.read_table('hs.txt',header=None,delim_whitespace=True)
data.columns=['nX','nY','nZ','Density']
grouped=data['Density'].groupby(data['nZ'])


#data=pd.read_table('../KCL_0_1_modi_T/volmap_HS.txt',header=None,delim_whitespace=True)
dataA=pd.read_table('8nm/Na_200mM/volmap_HS.txt',header=None,delim_whitespace=True)
#data=pd.read_table('hs.txt',header=None,delim_whitespace=True)
dataA.columns=['nX','nY','nZ','Density']
groupedA=dataA['Density'].groupby(dataA['nZ'])

#data=pd.read_table('../KCL_0_1_modi_T/volmap_HS.txt',header=None,delim_whitespace=True)
dataB=pd.read_table('12nm/Na_200mM/volmap_HS.txt',header=None,delim_whitespace=True)
#data=pd.read_table('hs.txt',header=None,delim_whitespace=True)
dataB.columns=['nX','nY','nZ','Density']
groupedB=dataB['Density'].groupby(dataB['nZ'])


#plt.plot(grouped.mean()*fraction) # positive without '-' negative sign, negative, should consider '-' sign
plt.plot(groupedB.mean()*fractionB,'b',label='12nm')
plt.plot(grouped.mean()*fraction,'r',label='6nm') # positive without '-' negative sign, negative, should consider '-' sign
plt.plot(groupedA.mean()*fractionA,'g',label='8nm')
plt.xlabel('Z-axis in Angstrom')
plt.xlim(0,360)
plt.ylabel('Density')
plt.legend(loc='best')
plt.legend(loc='upper right',bbox_to_anchor=(0.9,0.95))
#plt.title('Tot charge density over Z-axis (100ns in NVT ensemble)')
plt.title('HS charge density over Z-axis for Na ion')
plt.show()

# %%
#data=pd.read_table('../KCL_0_1_modi_T/volmap_tot.txt',header=None,delim_whitespace=True)
#data=pd.read_table('volmap_tot.txt',header=None,delim_whitespace=True)
#data.columns=['nX','nY','nZ','Density']
#grouped=data['Density'].groupby(data['nZ'])

#dataHS=pd.read_table('volmap_HS.txt',header=None,delim_whitespace=True)
dataHS=pd.read_table('volmap_HS.txt',header=None,delim_whitespace=True)
dataHS.columns=['nX','nY','nZ','DensityHS']
groupedHS=dataHS['DensityHS'].groupby(dataHS['nZ'])

dataN=pd.read_table('volmap_POT.txt',header=None,delim_whitespace=True)
dataN.columns=['nX','nY','nZ','DensityK']
groupedN=dataN['DensityK'].groupby(dataN['nZ'])

dataC=pd.read_table('volmap_CLA.txt',header=None,delim_whitespace=True)
dataC.columns=['nX','nY','nZ','DensityCl']
groupedC=dataC['DensityCl'].groupby(dataC['nZ'])

# %%
groupedHS.mean()[2:3]
# Out:
# Series([], Name: DensityHS, dtype: float64)

# %%
plt.plot(groupedHS.mean()*fraction,'r') # positive without '-' negative sign, negative, should consider '-' sign
plt.plot(groupedN.mean()*fraction,'g')
plt.plot(groupedC.mean()*fraction,'b')
plt.plot(groupedHS.mean()*fraction+groupedN.mean()*fraction+groupedC.mean()*fraction,'y',label='Net density')
plt.xlabel('Z-axis in Angstrom')
plt.ylabel('Density')
plt.legend(loc='best')
plt.legend(loc='upper right')
#plt.legend(loc='upper right',bbox_to_anchor=(0.3,0.95))
plt.title('Charge density over Z-axis (100ns in NVT ensemble)')
#plt.title('HS charge density over Z-axis (100ns in NVT ensemble)')
plt.show()

# %%
import scipy
import scipy.integrate as integrate
import scipy.special as special
resultsHS=integrate.trapz(groupedHS.mean()*fraction) #+integrate.trapz(groupedT.mean()*unit)
print resultsHS*40*40
resultsN=integrate.trapz(groupedN.mean()*fraction) #+integrate.trapz(groupedT.mean()*unit)
print resultsN*40*40
resultsC=integrate.trapz(groupedC.mean()*fraction) #+integrate.trapz(groupedT.mean()*unit)
print resultsC*40*40
net=integrate.trapz(groupedC.mean()*fraction)+integrate.trapz(groupedHS.mean()*fraction)+integrate.trapz(groupedN.mean()*fraction)
print net*40*40
# Out:
# -203.10519985925495
# 261.5846039116932
# -58.4121452960299
# 0.06725875640829493
